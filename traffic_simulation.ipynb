# %% [markdown]
# # Traffic Simulation

# %%
# %matplotlib inline

# %%
from sim_traffic import main

# %% [markdown]
# Our main function returns a graph of traffic over time for a simulation with 30 cars evenly spaced on a 1000 meter single-lane road loop.
# - Drivers want to go up to 120 km/hr.
# - The average car is 5 meters long.
# - Drivers want at least a number of meters equal to their speed in meters/second between them and the next car.
# - Drivers will accelerate 2 m/s up to their desired speed as long as they have room to do so.
# - If another car is too close, drivers will match that car's speed until they have room again.
# - If a driver would hit another car by continuing, they stop.
# - Drivers will randomly (10% chance each second) slow by 2 m/s.
# - This section of road is one lane going one way.

# %% [markdown]
# Each line represents a moment in time. Each car is shown as a different color, but since the color scheme is a gradient this may not be obvious.

# %%
main()
# Out:
# Mean Speed: 26.807650273224045
# Std Dev Speed: 9.269263271983613
# Optimal Speed: 36.07691354520766
# Legal Speed: 36
