# %%
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
from pandas import DataFrame, Series
# %matplotlib inline

# %%
from sim_traffic import main

# %%
main()
# Out:
# Mean Speed: 27.161748633879782
# Std Dev Speed: 8.909916775792167
# Optimal Speed: 36.07166540967195
