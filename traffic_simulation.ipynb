# %%
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
from pandas import DataFrame, Series
# %matplotlib inline

# %%
from sim_traffic import main

# %%
main()
# Out:
# Mean Speed: 27.469945355191257
# Std Dev Speed: 9.081185586345832
# Optimal Speed: 36.55113094153709
# Legal Speed: 36
