# %%
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
from pandas import DataFrame, Series
# %matplotlib inline

# %%
df = pd.DataFrame(np.random.rand(50, 4), columns=['a', 'b', 'c', 'd'])


df = DataFrame([[1,2,3,4,5],[5,6,7,8,9]])
df
# Out:
#            a         b         c         d
# 0   0.592765  0.277130  0.700058  0.943113
# 1   0.594015  0.822665  0.004803  0.064529
# 2   0.513875  0.769831  0.765589  0.124246
# 3   0.747567  0.091399  0.532783  0.087342
# 4   0.273082  0.854887  0.966269  0.370768
# 5   0.369926  0.272985  0.214381  0.393377
# 6   0.983681  0.921364  0.304591  0.351381
# 7   0.952668  0.902631  0.952523  0.052901
# 8   0.041290  0.711158  0.207291  0.939396
# 9   0.213714  0.783928  0.605444  0.565286
# 10  0.747644  0.361885  0.348663  0.953408
# 11  0.028314  0.633798  0.573238  0.431415
# 12  0.223437  0.979489  0.366533  0.950215
# 13  0.530206  0.688603  0.580022  0.380001
# 14  0.195122  0.532542  0.258003  0.588938
# 15  0.286300  0.225622  0.773693  0.955172
# 16  0.997913  0.625021  0.724132  0.070406
# 17  0.216665  0.067395  0.056731  0.938256
# 18  0.520168  0.004492  0.352106  0.678881
# 19  0.010472  0.712274  0.825480  0.262742
# 20  0.568625  0.370633  0.125564  0.376403
# ...

# %%
#df.plot(kind='scatter', x= df.index, y=[] )
