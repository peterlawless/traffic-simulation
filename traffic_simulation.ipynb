# %%
# %matplotlib inline

# %%
from sim_traffic import main

# %%
main()
# Out:
# Mean Speed: 27.674316939890712
# Std Dev Speed: 9.13317701050299
# Optimal Speed: 36.807493950393706
# Legal Speed: 36
